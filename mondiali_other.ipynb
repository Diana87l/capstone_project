# %% [markdown]
# - importo il file csv scaricato da Kaggle

# %%
import pandas as pd
df = pd.read_csv('E:\epicode\dati energia\kaggle\World Energy Consumption.csv')

# %% [markdown]
# - esploro il dataset

# %%
df.describe()
# Out:
#                year  coal_prod_change_pct  coal_prod_change_twh  \
# count  17432.000000           7445.000000          10394.000000
# mean    1973.094367             20.830774              8.798102
# std       34.333995            697.178744            135.503698
# min     1900.000000           -100.000000          -2326.870000
# 25%     1946.000000             -1.532000              0.000000
# 50%     1983.000000              0.000000              0.000000
# 75%     2002.000000              7.690000              0.334000
# max     2020.000000          44965.754000           3060.593000
#
#        gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# count         4.862000e+03          7893.000000          6521.000000
# mean          1.921623e+14            14.369018            18.242190
# std           1.339910e+16            85.415649           335.492675
# min          -1.000000e+02         -1054.320000          -100.000000
# ...

# %%
df.shape
# Out:
# (17432, 122)

# %%
df.head(5)
# Out:
#   iso_code      country  year  coal_prod_change_pct  coal_prod_change_twh  \
# 0      AFG  Afghanistan  1900                   NaN                   NaN
# 1      AFG  Afghanistan  1901                   NaN                   0.0
# 2      AFG  Afghanistan  1902                   NaN                   0.0
# 3      AFG  Afghanistan  1903                   NaN                   0.0
# 4      AFG  Afghanistan  1904                   NaN                   0.0
#
#    gas_prod_change_pct  gas_prod_change_twh  oil_prod_change_pct  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    oil_prod_change_twh  energy_cons_change_pct  ...  solar_elec_per_capita  \
# ...

# %% [markdown]
# - controllo la presenza dei valori nulli e il loro impatto sul totale dei dati

# %%
df.isnull().sum()
# Out:
# iso_code                   1802
# country                       0
# year                          0
# coal_prod_change_pct       9987
# coal_prod_change_twh       7038
#                           ...
# wind_share_energy         13148
# wind_cons_change_twh      13225
# wind_consumption          13142
# wind_elec_per_capita      11933
# wind_energy_per_capita    13142
# Length: 122, dtype: int64

# %%
df.notnull().sum()
# Out:
# iso_code                  15630
# country                   17432
# year                      17432
# coal_prod_change_pct       7445
# coal_prod_change_twh      10394
#                           ...
# wind_share_energy          4284
# wind_cons_change_twh       4207
# wind_consumption           4290
# wind_elec_per_capita       5499
# wind_energy_per_capita     4290
# Length: 122, dtype: int64

# %%
valori_mancanti=df.isna().sum() / len(df) * 100
valori_mancanti.sort_values(ascending=False)
valori_mancanti_df=pd.DataFrame(valori_mancanti)
valori_mancanti_df.head(10)
# Out:
#                                 0
# iso_code                10.337311
# country                  0.000000
# year                     0.000000
# coal_prod_change_pct    57.291189
# coal_prod_change_twh    40.374025
# gas_prod_change_pct     72.108765
# gas_prod_change_twh     54.721202
# oil_prod_change_pct     62.591785
# oil_prod_change_twh     50.866223
# energy_cons_change_pct  43.540615

# %% [markdown]
# - cerco le countries presenti (in maniera univoca) nel set di dati. Da questa lista estraggo poi quelle di interesse.

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia Pacific', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
#        'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'CIS', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Central America',
#        'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo',
#        'Cook Islands', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba',
#        'Cyprus', 'Czechia', 'Czechoslovakia',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Eastern Africa', 'Ecuador', 'Egypt',
# ...

# %% [markdown]
# - seleziono alcune colonne per creare un set customizzato e più piccolo rispetto quello iniziale

# %%
df=df[['country','year','energy_per_gdp', 'energy_per_capita','gdp', 'population']]

# %% [markdown]
# - scelgo di analizzare i Paesi dell' OPEC e alcuni extra ( Stati Uniti, Giappone, India, Canada, Cina, Russia)

# %%
df=df[df['year']>=2000]
countries=['Algeria','Angola', 'Congo', 'Equatorial Guinea', 'Gabon', 'Iran', 'Iraq', 'Kuwait','Lybia', 'Nigeria', 'Saudi Arabia',
           'United Arab Emirates', 'Venezuela','United States','Japan','India', 'Canada', 'China', 'Russia']
filtro_countries = df.loc[:, "country"].isin(countries)
df = df.loc[filtro_countries]

# %%
df
# Out:
#          country  year  energy_per_gdp  energy_per_capita           gdp  \
# 460      Algeria  2000           1.190           9662.271  2.520000e+11
# 461      Algeria  2001           1.233           9881.754  2.520000e+11
# 462      Algeria  2002           1.210          10106.442  2.660000e+11
# 463      Algeria  2003           1.166          10441.229  2.890000e+11
# 464      Algeria  2004           1.136          10697.854  3.080000e+11
# ...          ...   ...             ...                ...           ...
# 16683  Venezuela  2015           1.895          30422.200  4.830000e+11
# 16684  Venezuela  2016           2.097          27817.912  3.960000e+11
# 16685  Venezuela  2017             NaN          26974.738           NaN
# 16686  Venezuela  2018             NaN          23598.421           NaN
# 16687  Venezuela  2019             NaN          21691.926           NaN
#
#        population
# 460    31042000.0
# 461    31452000.0
# 462    31855000.0
# 463    32264000.0
# ...

# %% [markdown]
# - esporto il file in csv per poi utilizzarlo in power bi

# %%
df.to_csv('E:\epicode\dati energia\kaggle\mondiali_other.csv')

# %% [markdown]
# - richiamo il file salvato per fare un controllo dei valori NaN

# %%
import pandas as pd
df = pd.read_csv('E:\epicode\dati energia\kaggle\mondiali_other.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# country               0
# year                  0
# energy_per_gdp       62
# energy_per_capita    23
# gdp                  62
# population            8
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Unnamed: 0           368
# country              368
# year                 368
# energy_per_gdp       306
# energy_per_capita    345
# gdp                  306
# population           360
# dtype: int64
